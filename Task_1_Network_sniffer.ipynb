# %%
pip install scapy
# Out:
# Collecting scapy
#   Downloading scapy-2.5.0.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 17.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: scapy
#   Building wheel for scapy (setup.py) ... done
#   Created wheel for scapy: filename=scapy-2.5.0-py2.py3-none-any.whl size=1444327 sha256=d525ee19f3eac6069199836c3ab0ba38144d3dfe6fe686284bdb6606469e8da2
#   Stored in directory: /root/.cache/pip/wheels/82/b7/03/8344d8cf6695624746311bc0d389e9d05535ca83c35f90241d
# Successfully built scapy
# Installing collected packages: scapy
# Successfully installed scapy-2.5.0

# %%
from scapy.all import *

# %%
def packet_analyzer(packet):
  if packet.haslayer(IP):
    sour_ip=packet[IP].src
    dest_ip=packet[IP].dst
    protocol = packet[IP].proto
    print(f"IP Packet: {sour_ip} --> {dest_ip} Protocol: {protocol}")

  if packet.haslayer(TCP):
    sour_port=packet[TCP].sport
    dest_port=packet[TCP].dport
    print(f"TCP Packet: {sour_port} --> {dest_port} Payload: {str(packet[TCP].payload)}")

  if packet.haslayer(UDP):
    sour_port=packet[UDP].sourceport
    dest_port=packet[UDP].sestport
    print(f"UDP Packet: {sour_port} --> {dest_port} Payload: {str(packet[UDP].payload)}")

sniff(prn=packet_analyzer, store=0)
# Out:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 48416 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 48416 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 48416 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 48416 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 48416 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 48416 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 48416 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 48416 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56296 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56296 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56308 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56308 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56312 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56312 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 57346 --> 6000 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 57346 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 57346 --> 6000 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 6000 --> 57346 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 57346 --> 6000 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 56324 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 56324 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52014 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52014 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52014 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52014 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52014 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52014 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52014 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52014 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52014 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52014 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52014 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52014 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52014 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload:
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# IP Packet: 172.28.0.12 --> 172.28.0.1 Protocol: 6
# TCP Packet: 8080 --> 52018 Payload: Raw
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload:
# IP Packet: 172.28.0.1 --> 172.28.0.12 Protocol: 6
# TCP Packet: 52018 --> 8080 Payload: Raw
# <Sniffed: TCP:0 UDP:0 ICMP:0 Other:0>
